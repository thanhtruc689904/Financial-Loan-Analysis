# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (3.0.2)
# Requirement already satisfied: numpy>=2.3.3 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pandas) (2.4.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pandas) (2026.1)
# Requirement already satisfied: six>=1.5 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd

# %%
df = pd.read_csv('financial_loan.csv')

# %%
df.head()
# Out:
#         id address_state application_type emp_length              emp_title  \
# 0  1077430            GA       INDIVIDUAL   < 1 year                  Ryder
# 1  1072053            CA       INDIVIDUAL    9 years         MKC Accounting
# 2  1069243            CA       INDIVIDUAL    4 years  Chemat Technology Inc
# 3  1041756            TX       INDIVIDUAL   < 1 year    barnes distribution
# 4  1068350            IL       INDIVIDUAL  10+ years          J&J Steel Inc
#
#   grade home_ownership  issue_date last_credit_pull_date last_payment_date  \
# 0     C           RENT  11-02-2021            13-09-2021        13-04-2021
# 1     E           RENT  01-01-2021            14-12-2021        15-01-2021
# 2     C           RENT  05-01-2021            12-12-2021        09-01-2021
# 3     B       MORTGAGE  25-02-2021            12-12-2021        12-03-2021
# 4     A       MORTGAGE  01-01-2021            14-12-2021        15-01-2021
#
#    ... sub_grade        term  verification_status annual_income     dti  \
# 0  ...        C4   60 months      Source Verified       30000.0  0.0100
# 1  ...        E1   36 months      Source Verified       48000.0  0.0535
# 2  ...        C5   36 months         Not Verified       50000.0  0.2088
# 3  ...        B2   60 months      Source Verified       42000.0  0.0540
# 4  ...        A1   36 months             Verified       83000.0  0.0231
#
#   installment int_rate  loan_amount  total_acc  total_payment
# 0       59.83   0.1527         2500          4           1009
# 1      109.43   0.1864         3000          4           3939
# 2      421.65   0.1596        12000         11           3522
# 3       97.06   0.1065         4500          9           4911
# 4      106.53   0.0603         3500         28           3835
#
# [5 rows x 24 columns]

# %%
df['issue_date'] = pd.to_datetime(df['issue_date'], format='%d-%m-%Y')
df['month_name'] = df['issue_date'].dt.month_name()

# %%
df.head()
# Out:
#         id address_state application_type emp_length              emp_title  \
# 0  1077430            GA       INDIVIDUAL   < 1 year                  Ryder
# 1  1072053            CA       INDIVIDUAL    9 years         MKC Accounting
# 2  1069243            CA       INDIVIDUAL    4 years  Chemat Technology Inc
# 3  1041756            TX       INDIVIDUAL   < 1 year    barnes distribution
# 4  1068350            IL       INDIVIDUAL  10+ years          J&J Steel Inc
#
#   grade home_ownership issue_date last_credit_pull_date last_payment_date  \
# 0     C           RENT 2021-02-11            13-09-2021        13-04-2021
# 1     E           RENT 2021-01-01            14-12-2021        15-01-2021
# 2     C           RENT 2021-01-05            12-12-2021        09-01-2021
# 3     B       MORTGAGE 2021-02-25            12-12-2021        12-03-2021
# 4     A       MORTGAGE 2021-01-01            14-12-2021        15-01-2021
#
#    ...        term verification_status  annual_income     dti installment  \
# 0  ...   60 months     Source Verified        30000.0  0.0100       59.83
# 1  ...   36 months     Source Verified        48000.0  0.0535      109.43
# 2  ...   36 months        Not Verified        50000.0  0.2088      421.65
# 3  ...   60 months     Source Verified        42000.0  0.0540       97.06
# 4  ...   36 months            Verified        83000.0  0.0231      106.53
#
#   int_rate loan_amount  total_acc  total_payment  month_name
# 0   0.1527        2500          4           1009    February
# 1   0.1864        3000          4           3939     January
# 2   0.1596       12000         11           3522     January
# 3   0.1065        4500          9           4911    February
# 4   0.0603        3500         28           3835     January
#
# [5 rows x 25 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 38576 entries, 0 to 38575
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     38576 non-null  int64
#  1   address_state          38576 non-null  str
#  2   application_type       38576 non-null  str
#  3   emp_length             38576 non-null  str
#  4   emp_title              37138 non-null  str
#  5   grade                  38576 non-null  str
#  6   home_ownership         38576 non-null  str
#  7   issue_date             38576 non-null  datetime64[us]
#  8   last_credit_pull_date  38576 non-null  str
#  9   last_payment_date      38576 non-null  str
#  10  loan_status            38576 non-null  str
#  11  next_payment_date      38576 non-null  str
#  12  member_id              38576 non-null  int64
#  13  purpose                38576 non-null  str
#  14  sub_grade              38576 non-null  str
#  15  term                   38576 non-null  str
#  16  verification_status    38576 non-null  str
#  17  annual_income          38576 non-null  float64
#  18  dti                    38576 non-null  float64
#  19  installment            38576 non-null  float64
#  20  int_rate               38576 non-null  float64
#  21  loan_amount            38576 non-null  int64
#  22  total_acc              38576 non-null  int64
#  23  total_payment          38576 non-null  int64
#  24  month_name             38576 non-null  str
# dtypes: datetime64[us](1), float64(4), int64(5), str(15)
# memory usage: 7.4 MB

# %%
df.describe()
# Out:
#                  id                  issue_date     member_id  annual_income  \
# count  3.857600e+04                       38576  3.857600e+04   3.857600e+04
# mean   6.810371e+05  2021-07-16 02:31:35.562007  8.476515e+05   6.964454e+04
# min    5.473400e+04         2021-01-01 00:00:00  7.069900e+04   4.000000e+03
# 25%    5.135170e+05         2021-04-11 00:00:00  6.629788e+05   4.150000e+04
# 50%    6.627280e+05         2021-07-11 00:00:00  8.473565e+05   6.000000e+04
# 75%    8.365060e+05         2021-10-11 00:00:00  1.045652e+06   8.320050e+04
# max    1.077501e+06         2021-12-12 00:00:00  1.314167e+06   6.000000e+06
# std    2.113246e+05                         NaN  2.668105e+05   6.429368e+04
#
#                 dti   installment      int_rate   loan_amount     total_acc  \
# count  38576.000000  38576.000000  38576.000000  38576.000000  38576.000000
# mean       0.133274    326.862965      0.120488  11296.066855     22.132544
# min        0.000000     15.690000      0.054200    500.000000      2.000000
# 25%        0.082100    168.450000      0.093200   5500.000000     14.000000
# 50%        0.134200    283.045000      0.118600  10000.000000     20.000000
# 75%        0.185900    434.442500      0.145900  15000.000000     29.000000
# max        0.299900   1305.190000      0.245900  35000.000000     90.000000
# std        0.066662    209.092000      0.037164   7460.746022     11.392282
#
#        total_payment
# count   38576.000000
# mean    12263.348533
# min        34.000000
# 25%      5633.000000
# 50%     10042.000000
# 75%     16658.000000
# max     58564.000000
# std      9051.104777

# %%
df.isnull().sum()
# Out:
# id                          0
# address_state               0
# application_type            0
# emp_length                  0
# emp_title                1438
# grade                       0
# home_ownership              0
# issue_date                  0
# last_credit_pull_date       0
# last_payment_date           0
# loan_status                 0
# next_payment_date           0
# member_id                   0
# purpose                     0
# sub_grade                   0
# term                        0
# verification_status         0
# annual_income               0
# dti                         0
# installment                 0
# int_rate                    0
# loan_amount                 0
# total_acc                   0
# total_payment               0
# month_name                  0
# dtype: int64

# %%
df['emp_title'] = df['emp_title'].fillna('Unknown')

# %%
df.isnull().sum()
# Out:
# id                       0
# address_state            0
# application_type         0
# emp_length               0
# emp_title                0
# grade                    0
# home_ownership           0
# issue_date               0
# last_credit_pull_date    0
# last_payment_date        0
# loan_status              0
# next_payment_date        0
# member_id                0
# purpose                  0
# sub_grade                0
# term                     0
# verification_status      0
# annual_income            0
# dti                      0
# installment              0
# int_rate                 0
# loan_amount              0
# total_acc                0
# total_payment            0
# month_name               0
# dtype: int64

# %%
# !pip install pymysql sqlalchemy
# Out:
# Requirement already satisfied: pymysql in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (1.1.2)
# Requirement already satisfied: sqlalchemy in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (2.0.49)
# Requirement already satisfied: greenlet>=1 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from sqlalchemy) (3.4.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from sqlalchemy) (4.15.0)

# %%
from sqlalchemy import create_engine

# MySQL connection
username = "root"
password = "123456789"
host = "localhost"
port = "3306"
database = "financial_loan"

engine = create_engine(f"mysql+pymysql://{username}:{password}@{host}:{port}/{database}")

# Write DataFrame to MySQL
table_name = "financial_loan"   # choose any table name
df.to_sql(table_name, engine, if_exists="replace", index=False)

# Read back sample
pd.read_sql("SELECT * FROM financial_loan LIMIT 5;", engine)
# Out:
#         id address_state application_type emp_length              emp_title  \
# 0  1077430            GA       INDIVIDUAL   < 1 year                  Ryder
# 1  1072053            CA       INDIVIDUAL    9 years         MKC Accounting
# 2  1069243            CA       INDIVIDUAL    4 years  Chemat Technology Inc
# 3  1041756            TX       INDIVIDUAL   < 1 year    barnes distribution
# 4  1068350            IL       INDIVIDUAL  10+ years          J&J Steel Inc
#
#   grade home_ownership issue_date last_credit_pull_date last_payment_date  \
# 0     C           RENT 2021-02-11            13-09-2021        13-04-2021
# 1     E           RENT 2021-01-01            14-12-2021        15-01-2021
# 2     C           RENT 2021-01-05            12-12-2021        09-01-2021
# 3     B       MORTGAGE 2021-02-25            12-12-2021        12-03-2021
# 4     A       MORTGAGE 2021-01-01            14-12-2021        15-01-2021
#
#    ...        term verification_status  annual_income     dti installment  \
# 0  ...   60 months     Source Verified        30000.0  0.0100       59.83
# 1  ...   36 months     Source Verified        48000.0  0.0535      109.43
# 2  ...   36 months        Not Verified        50000.0  0.2088      421.65
# 3  ...   60 months     Source Verified        42000.0  0.0540       97.06
# 4  ...   36 months            Verified        83000.0  0.0231      106.53
#
#   int_rate loan_amount  total_acc  total_payment  month_name
# 0   0.1527        2500          4           1009    February
# 1   0.1864        3000          4           3939     January
# 2   0.1596       12000         11           3522     January
# 3   0.1065        4500          9           4911    February
# 4   0.0603        3500         28           3835     January
#
# [5 rows x 25 columns]
